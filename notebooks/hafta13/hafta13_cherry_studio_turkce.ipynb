# %% [markdown]
# # Cherry Studio — Türkçe Destekli RAG
#
# > **Hafta 13 · Lokal RAG ve Kendi Verinle Konuşma** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Çoklu API + Ollama + Türkçe dostu arayüz.
#
# ---

# %% [markdown]
# ## 1. Kurulum
#
# cherry-ai.com → indir.

# %% [markdown]
# ## 2. Çoklu Provider
#
# OpenAI + Gemini + Claude + Ollama hepsi tek panelde. API key yoksa lokal Ollama yeterli.

# %% [markdown]
# ## 3. Knowledge Base
#
# Ayarlar → Knowledge Base → Yeni → PDF yükle → workspace oluştur.

# %% [markdown]
# ## 4. Türkçe Avantaj
#
# Çince yapımı ama Türkçe arayüz çevirisi mevcut. Türkçe modellerle (Trendyol-LLM, KocLM) kolay entegrasyon.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Cherry Studio + Ollama tam offline iş akışı kur
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
