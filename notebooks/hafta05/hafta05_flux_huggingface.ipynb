# %% [markdown]
# # Flux Schnell — HF Spaces (Ücretsiz)
#
# > **Hafta 5 · Görsel Üretim Atölyesi** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Açık kaynak en iyi diffusion modeli.
#
# ---

# %% [markdown]
# ## 1. HF Spaces
#
# huggingface.co/spaces → Flux Schnell ara → Free GPU ile dene.

# %% [markdown]
# ## 2. Schnell vs Dev vs Pro
#
# Schnell: 4 step, en hızlı, ücretsiz. Dev: 28 step, daha kaliteli. Pro: API.

# %% [markdown]
# ## 3. Local Çalıştırma
#
# Hafta 12'deki lokal LLM gibi, Flux'u da kendi GPU'nda çalıştırabilirsin (16GB+ VRAM).

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** HF Spaces'tan 5 görsel üret
# **Görev 2.** Flux Schnell × Imagen 3 kıyas et
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
