# %% [markdown]
# # Midjourney v6.1 Atölyesi
#
# > **Hafta 5 · Görsel Üretim Atölyesi** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Discord ve Web — sanat değeri en yüksek.
#
# ---

# %% [markdown]
# ## 1. Erişim
#
# midjourney.com — 10 USD/ay, Discord veya web.

# %% [markdown]
# ## 2. /imagine
#
# Discord'da `/imagine prompt: ...` ile başlat.

# %% [markdown]
# ## 3. Parametreler
#
# --ar 16:9 (aspect), --s 250 (stilize), --v 6 (versiyon), --niji (anime).

# %% [markdown]
# ## 4. Variation, Upscale
#
# Ürettiği 4 görselden seçim. Variation = benzer üretim, Upscale = yüksek çözünürlük.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** 1 karakter yarat, 5 farklı pozda tutarlı şekilde üret (--cref)
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
