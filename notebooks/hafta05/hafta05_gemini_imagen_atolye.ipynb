# %% [markdown]
# # Google AI Studio + Imagen 3
#
# > **Hafta 5 · Görsel Üretim Atölyesi** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Ücretsiz, Türkiye'den erişilebilir, hızlı.
#
# ---

# %% [markdown]
# ## 1. Erişim
#
# aistudio.google.com → Imagen 3 → Free tier (haftalık limitli).

# %% [markdown]
# ## 2. Prompt Yapısı
#
# Imagen, kısa açıklayıcı prompt'u sever. "Bir kedi" değil, "Sokak kedisi, gri tüylü, mavi göz, fotogerçekçi, doğal ışık".

# %% [markdown]
# ## 3. Aspect Ratio
#
# 1:1, 9:16, 16:9 — sosyal medya için seç.

# %% [markdown]
# ## 4. Negatif Prompt
#
# "--no text" — Türkçe metin yazımında zayıf, hata yapar.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Mesleğine özel 5 görsel üret
# **Görev 2.** Aynı prompt × 4 farklı aspect ratio dene
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
