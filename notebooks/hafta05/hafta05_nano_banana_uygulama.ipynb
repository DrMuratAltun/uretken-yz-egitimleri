# %% [markdown]
# # Nano Banana — Türk Yapımı
#
# > **Hafta 5 · Görsel Üretim Atölyesi** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Yerli görsel üretim aracı (docs/Nano Banana Uygulamaları.docx referans).
#
# ---

# %% [markdown]
# ## 1. Tanıtım
#
# Türk yapımı görsel + üretken YZ aracı. Türkçe arayüz, yerel kullanım odaklı.

# %% [markdown]
# ## 2. Kullanım Senaryoları
#
# Eğitim materyali, infografi, sosyal medya görseli.

# %% [markdown]
# ## 3. Avantajlar
#
# Türkçe destek, KVKK uyumu, yerli ekosistem desteği.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Nano Banana'da bir mesleki proje üret, blogda tanıt
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
