# %% [markdown]
# # Kamera, Işık, Stil — Prompt Geliştirme
#
# > **Hafta 5 · Görsel Üretim Atölyesi** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Bir görseli profesyonelleştiren detaylar (docs/Kamera açıları.docx referans).
#
# ---

# %% [markdown]
# ## 1. Kamera Açıları
#
# low angle (alttan), high angle (üstten), Dutch angle (eğik), POV (1. şahıs), bird's eye (kuş bakışı), Worm's eye (solucan bakışı).

# %% [markdown]
# ## 2. Mercek/Lens
#
# wide-angle (geniş), telephoto (uzak yakın çekim), macro (yakın), fisheye, portrait (85mm).

# %% [markdown]
# ## 3. Işık
#
# golden hour, blue hour, harsh sunlight, soft diffused light, neon, candle light, rim light.

# %% [markdown]
# ## 4. Sanat Akımı
#
# impressionist, art nouveau, baroque, minimalist, brutalist, watercolor, oil painting, pencil sketch.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Aynı sahneyi 5 farklı kamera açısı ile üret
# **Görev 2.** 5 farklı sanat akımıyla aynı konu
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
