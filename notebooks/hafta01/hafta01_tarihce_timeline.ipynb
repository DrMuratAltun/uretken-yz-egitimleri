# %% [markdown]
# # Üretken YZ Tarihçesi — Turing'den 2026'ya
#
# > **Hafta 1 · Üretken YZ'ye Giriş** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** YZ'nin köklerinden bugünün multimodal modellerine uzanan görsel zaman çizgisi.
#
# ---

# %% [markdown]
# ## 🎯 Hedefler
#
# Bu notebook'u tamamladığında:
#
# - 7 dönüm noktasını sıralı olarak hatırlamak
# - Cahit Arf (1958) ve Türkiye'nin yerini görmek
# - Transformer (2017) öncesi/sonrası ayrımını anlamak
#
# ---

# %% [markdown]
# ## 1. 1950 — Turing Testi
#
# Alan Turing "Computing Machinery and Intelligence" makalesinde "Makineler düşünebilir mi?" sorusunu sordu. Cevap arayışı YZ'nin doğum tetikleyicisi oldu.

# %% [markdown]
# ## 2. 1956 — Dartmouth Konferansı
#
# John McCarthy ve ekibi YZ'yi resmi bir araştırma alanı olarak kurdu. "Artificial Intelligence" terimi burada doğdu.

# %% [markdown]
# ## 3. 1958 — Cahit Arf: "Makine Düşünebilir mi?"
#
# Türk matematikçi Cahit Arf, **1958'de** Erzurum Atatürk Üniversitesi açılış konuşmasında bu soruyu Türkçe olarak ele aldı. Türkiye'nin YZ kökü 60+ yıl öncesine uzanır.

# %% [markdown]
# > ℹ️ docs/cahit-arf-makine-dusunebilir-mi-orjinal.pdf — orijinal makale.

# %% [markdown]
# ## 4. 2014 — GAN (Üretken Çekişmeli Ağlar)
#
# Ian Goodfellow, GAN'leri (Generative Adversarial Networks) yayınladı. "Üretken çağ" başladı — fotogerçek görsel üretimi mümkün hale geldi.

# %% [markdown]
# ## 5. 2017 — "Attention is All You Need" (Transformer)
#
# Google ekibi Transformer mimarisini yayınladı. Bu, BERT/GPT/Claude/Gemini gibi tüm modern LLM'lerin temelidir.

# %% [markdown]
# > 💡 **İpucu:** Transformer öncesi: kısa context, RNN/LSTM. Sonrası: uzun context, paralel hesaplama, ölçeklenebilir.

# %% [markdown]
# ## 6. 2022 — ChatGPT (30 Kasım)
#
# OpenAI, GPT-3.5'i ChatGPT olarak halka açtı. 5 günde 1 milyon kullanıcıya ulaştı — tüm zamanların en hızlı yayılan teknolojik ürünü.

# %% [markdown]
# ## 7. 2024-2026 — Multimodal & Agent çağı
#
# GPT-4o, Gemini 2.5, Claude Sonnet 4.6 — tek modelle metin+ses+görsel+video. MCP (Anthropic), Computer Use (browser kontrol), agentic workflows.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** 7 dönüm noktasını kendi sözlerinle özetleyen 1 sayfalık zaman çizgisi hazırla.
# **Görev 2.** Her dönüm noktası için "şimdi olsa nasıl olurdu?" düşünce deneyi yap (örneğin "Cahit Arf'ın 1958'de bir LLM'i olsaydı?").
# **Görev 3.** Cahit Arf makalesini oku (docs/), 1 sayfa Türkçe özetle.
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Sonraki: `hafta01_etik_senaryolar.ipynb`
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
