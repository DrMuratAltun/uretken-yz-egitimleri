# %% [markdown]
# # Open WebUI — Docker ile ChatGPT Benzeri Arayüz
#
# > **Hafta 12 · Lokal LLM Kurulumu** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Çoklu kullanıcı, profil, RAG, web search — hepsi açık kaynak.
#
# ---

# %% [markdown]
# ## 🎯 Hedefler
#
# Bu notebook'u tamamladığında:
#
# - Docker ile kurulum
# - Ollama bağlama
# - Aile/takım için arayüz açma
#
# ---

# %% [markdown]
# ## 1. Docker Komutu
#
# ```bash
# docker run -d -p 3000:8080 \
#   --add-host=host.docker.internal:host-gateway \
#   -v open-webui:/app/backend/data \
#   --name open-webui --restart always \
#   ghcr.io/open-webui/open-webui:main
# ```
#
# localhost:3000 → ilk admin kayıt.

# %% [markdown]
# ## 2. Ollama Bağlama
#
# Settings → Connections → Ollama URL: `http://host.docker.internal:11434`. Modeller otomatik gelir.

# %% [markdown]
# ## 3. Çoklu Kullanıcı
#
# Aile / takım için profil aç. RBAC (Admin / User) mevcut.

# %% [markdown]
# ## 4. Documents (RAG)
#
# Workspace → Documents → PDF yükle → soru sor (Hafta 13'te derinleşeceğiz).

# %% [markdown]
# ## 5. VPS'te Kurulum
#
# Hetzner / Oracle Free Tier VPS'te aynı Docker komutu + nginx reverse proxy → kendi domaininden erişim.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Open WebUI'yi yerelde Docker ile kur, aile üyesine erişim ver
# **Görev 2.** VPS'e kur (opsiyonel, ileri)
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
