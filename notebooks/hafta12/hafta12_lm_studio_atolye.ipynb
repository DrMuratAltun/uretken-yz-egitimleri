# %% [markdown]
# # LM Studio Atölyesi (GUI)
#
# > **Hafta 12 · Lokal LLM Kurulumu** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** GUI seven kullanıcılar için — terminal yok, model arama + sohbet.
#
# ---

# %% [markdown]
# ## 🎯 Hedefler
#
# Bu notebook'u tamamladığında:
#
# - LM Studio kurulum
# - Model arama ve indirme
# - Local server ile API erişimi
#
# ---

# %% [markdown]
# ## 1. Kurulum
#
# lmstudio.ai → indir → kur (Mac/Win/Linux). 1.5 GB.

# %% [markdown]
# ## 2. Model Arama
#
# Search'te "Qwen 2.5 7B Instruct GGUF" yaz. Q4_K_M kuantizasyonunu seç (en dengeli).

# %% [markdown]
# ## 3. Sohbet Modu
#
# Chat sekmesi → model seç → konuş. Sistem prompt'u yan panelden.

# %% [markdown]
# ## 4. Local Server
#
# Local Server → "Start Server" → port 1234. Artık OpenAI API uyumlu endpoint!
#
# ```python
# import openai
# client = openai.OpenAI(base_url="http://localhost:1234/v1", api_key="not-needed")
# response = client.chat.completions.create(...)
# ```

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** LM Studio ile 3 model dene
# **Görev 2.** Local Server'ı OpenAI client ile kullan
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
