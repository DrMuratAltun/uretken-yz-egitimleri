# %% [markdown]
# # v0.dev + Vercel — No-Code Arayüz + AI
#
# > **Hafta 14 · API ile Üretken YZ + Capstone** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Promptdan ürüne, kod yazmadan.
#
# ---

# %% [markdown]
# ## 1. v0.dev
#
# v0.dev → "Bir kişisel YZ asistanı, sohbet arayüzü" yaz → Next.js + Tailwind + shadcn UI hazır.

# %% [markdown]
# ## 2. AI Bağla
#
# v0'da Gemini/OpenAI/Anthropic SDK seç → API key gir → backend route otomatik.

# %% [markdown]
# ## 3. Vercel'e Deploy
#
# v0 → "Deploy to Vercel" tek tık → Vercel hesabı bağla → canlı URL.

# %% [markdown]
# ## 4. Custom Domain
#
# Vercel → Settings → Domains → kendi domain'ini bağla.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** v0.dev ile bir YZ uygulaması üret, Vercel'e deploy et
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
