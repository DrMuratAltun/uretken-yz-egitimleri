# %% [markdown]
# # Capstone Proje Şablonu
#
# > **Hafta 14 · API ile Üretken YZ + Capstone** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** 14 haftanın sentezi olan bir ürün üret.
#
# ---

# %% [markdown]
# ## 🎯 Hedefler
#
# Bu notebook'u tamamladığında:
#
# - Capstone proje seçimi
# - Mimari tasarımı
# - Sunum + sertifika
#
# ---

# %% [markdown]
# ## 1. Adım 1 — Sorun Seç
#
# Kendi mesleğinde yıllardır seni yoran 1 sorun seç. Örnekler:
# - "Veliye haftalık öğrenci raporu yazmak"
# - "Hasta dosyalarında hızlı arama"
# - "Aylık vergi tablolarını analiz etmek"
# - "Kitap yazarken karakter takibi"

# %% [markdown]
# ## 2. Adım 2 — Sentez Bileşenleri
#
# Aşağıdakilerden en az 3'ünü dahil et:
#
# - ✅ Sohbet arayüzü (Hafta 3, 14)
# - ✅ Görsel/ses/video üretimi (Hafta 5-7)
# - ✅ NotebookLM ya da AnythingLLM ile bilgi tabanı (Hafta 4, 13)
# - ✅ Otomasyon akışı (Hafta 9 — Zapier/n8n/Make)
# - ✅ Lokal LLM (Hafta 12 — Ollama)
# - ✅ API tabanlı asistan (Hafta 14 — Gemini)

# %% [markdown]
# ## 3. Adım 3 — Mimari Diyagram
#
# Mermaid ya da Excalidraw ile bir görsel diyagram çiz:
#
# ```mermaid
# graph LR
#     A[Kullanıcı] --> B[Streamlit UI]
#     B --> C[Gemini 2.5]
#     B --> D[AnythingLLM RAG]
#     D --> E[PDF Klasörüm]
#     C --> F[Telegram Bot]
# ```

# %% [markdown]
# ## 4. Adım 4 — Geliştir
#
# Hafta 14'teki Streamlit şablonunu temel al, kendi mantığını ekle.

# %% [markdown]
# ## 5. Adım 5 — Deploy
#
# HF Spaces / Vercel / Open WebUI — biri yeter.

# %% [markdown]
# ## 6. Adım 6 — README + Demo Video
#
# - README: ne yapar, kim için, nasıl kullanılır
# - Demo video: Hafta 7'de öğrendiğin pipeline ile (senaryo → görsel → ses → video)
# - Mimari diyagram: yukarıdaki mermaid

# %% [markdown]
# ## 7. Adım 7 — Sunum Günü
#
# Atölyenin son haftasının 6. saatinde:
# - 5 dakika ürün demosu
# - 2 dakika soru-cevap
# - Sertifika töreni 🎓

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Capstone projeni seç, mimari diyagramını çiz, başla — atölye sonu sunum günü için tamamla
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
