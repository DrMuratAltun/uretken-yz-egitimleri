# %% [markdown]
# # ElevenLabs Türkçe + Ses Klonlama
#
# > **Hafta 6 · Ses, TTS ve Müzik** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Multilingual v2 ile Türkçe doğallık + 30 saniyede ses klonu.
#
# ---

# %% [markdown]
# ## 1. Voice Library
#
# Hazır Türkçe sesler (kadın/erkek, genç/yetişkin). Premium'da daha çok seçenek.

# %% [markdown]
# ## 2. Voice Cloning (Etik!)
#
# 30 saniyelik temiz ses örneği → klon. Hangi onayla, kim için olduğunu kayıt altına al!

# %% [markdown]
# ## 3. SSML / Etiketler
#
# `<break time="500ms"/>`, `[laughter]`, `[whisper]` ile detaylı kontrol.

# %% [markdown]
# ## 4. Maliyet
#
# Free: 10 dk/ay. Starter: 5 USD, 30 dk/ay.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Tanıtım metnini 3 farklı sesle dublajla
# **Görev 2.** Etik onaylı bir voice clone yap (kendi sesin)
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
