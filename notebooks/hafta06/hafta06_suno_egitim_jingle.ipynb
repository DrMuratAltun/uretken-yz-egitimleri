# %% [markdown]
# # Suno ile Müzik Üretimi
#
# > **Hafta 6 · Ses, TTS ve Müzik** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Eğitim için marş, jingle, ders açılış müziği.
#
# ---

# %% [markdown]
# ## 1. Suno v4
#
# Tek prompt → tam şarkı (sözlü). 50 free credit, sonra 8 USD/ay.

# %% [markdown]
# ## 2. Custom Mode
#
# "Style of Music" + "Lyrics" — Türkçe destekli.

# %% [markdown]
# ## 3. Eğitimde Kullanım
#
# Sınıfa marş, ders konuları için akılda kalıcı şarkı, çocuklara yaratıcı projeler.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Sınıf/takım için bir marş üret
# **Görev 2.** Bir konu için akılda kalıcı eğitim şarkısı yaz
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
