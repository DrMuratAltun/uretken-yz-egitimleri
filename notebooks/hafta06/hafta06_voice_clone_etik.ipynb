# %% [markdown]
# # Voice Cloning Etiği — Onay Protokolü
#
# > **Hafta 6 · Ses, TTS ve Müzik** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** KVKK + deepfake yasası + meslek etiği çerçevesi.
#
# ---

# %% [markdown]
# ## 1. Yasal Çerçeve
#
# 6698 KVKK kapsamında ses kişisel veridir. Sahibin yazılı onayı olmadan klonlama yasal değil.

# %% [markdown]
# ## 2. Onay Protokolü Şablonu
#
# 1) Onay belgesi imzalat (kim, ne zaman, hangi amaçla, ne kadar süre)
# 2) Kullanım sınırı tanımla
# 3) Geri çekilme hakkı belirt
# 4) Klon dosyasını saklama süresi sınırla.

# %% [markdown]
# ## 3. Deepfake Riski
#
# Klonladığın ses başkası tarafından kötüye kullanılabilir — hash + watermark düşün.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Ailendeki birinin sesini onaylı bir şekilde klonla, eğitim videolarında kullan
# **Görev 2.** Onay belgesi şablonunu mesleki kullanım için özelleştir
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
