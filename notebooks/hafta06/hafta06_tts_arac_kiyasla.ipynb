# %% [markdown]
# # TTS Araç Kıyası — Aynı Metin × 5 Araç
#
# > **Hafta 6 · Ses, TTS ve Müzik** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** ElevenLabs, OpenAI TTS, Gemini TTS, Azure, Google Cloud — Türkçe doğallık testi.
#
# ---

# %% [markdown]
# ## 1. Test Metni
#
# Bir 10-cümlelik Türkçe metin yaz (deyimler, sayılar, özel adlar dahil). Aynı metni 5 araca seslendirt.

# %% [markdown]
# ## 2. Değerlendirme
#
# Doğallık, ı/ğ/ü/ö/ş/ç doğruluğu, vurgu, tempo.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Kendi alanın için ideal TTS'i belirle, kaynak listesi tut
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
