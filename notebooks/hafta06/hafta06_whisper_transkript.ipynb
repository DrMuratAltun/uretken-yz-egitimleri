# %% [markdown]
# # Whisper STT — Video → Altyazı
#
# > **Hafta 6 · Ses, TTS ve Müzik** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Open-source, Türkçe %95+ doğruluk.
#
# ---

# %% [markdown]
# ## 1. OpenAI Whisper
#
# Açık kaynak, free. large-v3 modeli en iyi. Colab'da ücretsiz çalıştırılabilir.

# %% [markdown]
# ## 2. Türkçe Performans
#
# Doğal konuşma %95+. Argo, gürültü, çok hızlı konuşma → düşer.

# %% [markdown]
# ## 3. SRT Üretimi
#
# Otomatik altyazı (SRT format) üretir. YouTube'a direkt yüklenir.

# %% [markdown]
# ## 4. MacWhisper / WhisperX
#
# GUI alternatifleri. Çoklu konuşmacı ayrımı için WhisperX.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Kendi 1 saatlik dersini transkript et
# **Görev 2.** Otomatik SRT altyazı yap, YouTube'a yükle
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
