# %% [markdown]
# # NotebookLM Alternatifleri
#
# > **Hafta 4 · NotebookLM ve Bilgi Yönetimi** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Claude Projects, ChatGPT Knowledge, Google AI Studio Files — kıyas.
#
# ---

# %% [markdown]
# ## 1. Claude Projects
#
# Daha sıkı kaynak kontrolü, Artifacts ile ek özellik. Ücretsiz katmanı yok.

# %% [markdown]
# ## 2. ChatGPT Knowledge
#
# Custom GPT içine doküman yükleme. Audio yok ama Code Interpreter var.

# %% [markdown]
# ## 3. AI Studio Files
#
# Gemini'nin gelişmekte olan özelliği — büyük 2M context'le 100MB+ tek doküman.

# %% [markdown]
# ## 4. Karar Matrisi
#
# Türkçe podcast → NotebookLM. Kod + doküman → Claude. Excel/Sheets entegrasyonu → ChatGPT. Çok büyük tek doküman → AI Studio.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Aynı 5 PDF'i 4 araca yükle, soru-cevap kıyaslaması yap
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
