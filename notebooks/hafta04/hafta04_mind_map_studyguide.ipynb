# %% [markdown]
# # Mind Map ve Study Guide
#
# > **Hafta 4 · NotebookLM ve Bilgi Yönetimi** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** NotebookLM'in 2024 sonu eklenen özellikleri.
#
# ---

# %% [markdown]
# ## 1. Mind Map
#
# Tek tuşla kaynaklarını görsel haritaya çevirir. Konu hiyerarşisini saniyelerde görmenin en hızlı yolu.

# %% [markdown]
# ## 2. Briefing Doc
#
# 5-10 sayfa kaynak özeti — toplantı brifingi için ideal.

# %% [markdown]
# ## 3. Study Guide
#
# Sınava hazırlık formatında — kavramlar, sorular, cevaplar.

# %% [markdown]
# ## 4. Timeline
#
# Olay sırası — tarih dersi için altın değerinde.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Kendi alanında 1 Mind Map üret, sınıfta/takımda paylaş
# **Görev 2.** Bir konu için Study Guide oluştur, kullanım sürecini raporla
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
