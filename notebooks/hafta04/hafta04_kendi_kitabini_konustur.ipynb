# %% [markdown]
# # Kendi Kitabınla Konuş
#
# > **Hafta 4 · NotebookLM ve Bilgi Yönetimi** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** 5 PDF yükle, 20 soru-cevap atölyesi.
#
# ---

# %% [markdown]
# ## 1. Kaynak Hazırlığı
#
# PDF'leri kontrol et: OCR yapılmış mı? Resim ağırlıklı PDF'lerde NotebookLM zayıf.

# %% [markdown]
# ## 2. Soru Tipi 1: Tanımsal
#
# "X nedir?" — direkt cevap, kaynak alıntılı.

# %% [markdown]
# ## 3. Soru Tipi 2: Sentez
#
# "X ile Y arasındaki ilişki nedir?" — birden fazla kaynaktan derler.

# %% [markdown]
# ## 4. Soru Tipi 3: Eleştirel
#
# "Yazarın X argümanına karşı 3 zayıf nokta?" — analitik düşünce.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** 10 soruluk doğruluk testi yap
# **Görev 2.** NotebookLM'in halüsinasyon yaptığı 1 örnek bul ve raporla
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
