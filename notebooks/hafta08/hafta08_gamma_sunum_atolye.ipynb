# %% [markdown]
# # Gamma — Sunum Üretim Atölyesi
#
# > **Hafta 8 · Yazı, Sunum, Doküman, Ofis** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** 20 slaytlık sunum 5 dakikada.
#
# ---

# %% [markdown]
# ## 1. Erişim
#
# gamma.app — 400 free credits.

# %% [markdown]
# ## 2. Prompt → Sunum
#
# "Üretken YZ giriş, 20 slayt, lise öğretmenleri için" yaz, gerisini Gamma yapsın.

# %% [markdown]
# ## 3. Tema ve Marka
#
# Renk paleti, font, logo — kurumsal şablon olarak kaydet.

# %% [markdown]
# ## 4. Edit ve İhraç
#
# Slaytları düzenleyebilir, PDF/PPT/PNG ihraç edebilir.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Mesleğine özel 20 slaytlık sunum üret, PowerPoint ile kıyasla
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
