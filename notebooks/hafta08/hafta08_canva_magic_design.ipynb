# %% [markdown]
# # Canva Magic Design
#
# > **Hafta 8 · Yazı, Sunum, Doküman, Ofis** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Pazarlama görselleri tek prompt'la.
#
# ---

# %% [markdown]
# ## 1. Magic Design
#
# Tek prompt → 8 farklı tasarım önerisi (sosyal medya, sunum, broşür).

# %% [markdown]
# ## 2. Brand Kit
#
# Logo, renk paleti, font — bir kez tanımla, her tasarıma otomatik.

# %% [markdown]
# ## 3. Magic Write
#
# Canva içinden metin yazma + görsel üretme entegre.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Mesleğine özel marka kiti kur, 5 farklı paylaşım tasarla
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
