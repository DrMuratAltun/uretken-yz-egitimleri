# %% [markdown]
# # ChatPDF — Araştırma Akışı
#
# > **Hafta 8 · Yazı, Sunum, Doküman, Ofis** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Akademik makale, hukuki belge, teknik şartname ile sohbet.
#
# ---

# %% [markdown]
# ## 1. Yükleme
#
# chatpdf.com → 120 sayfa free / belge.

# %% [markdown]
# ## 2. Soru Tipleri
#
# Özet, tanım, eleştiri, atıf bulma.

# %% [markdown]
# ## 3. Multi-PDF
#
# Ücretli: birden fazla belge aynı anda — meta-analiz için ideal.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** 5 mesleki PDF'inle ChatPDF'i NotebookLM'e karşı kıyasla
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
