# %% [markdown]
# # Toplantı Asistanları — Otter, tldv, Fireflies
#
# > **Hafta 8 · Yazı, Sunum, Doküman, Ofis** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Otomatik özet + aksiyon maddeleri.
#
# ---

# %% [markdown]
# ## 1. Otter.ai
#
# Real-time transcript, özet, action items. Türkçe destek geldi.

# %% [markdown]
# ## 2. tldv.io
#
# Zoom/Meet otomatik kaydı + özet. Free tier güçlü.

# %% [markdown]
# ## 3. Fireflies.ai
#
# Daha "kurumsal" — CRM, Slack entegrasyonu.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Bir haftalık toplantılarını 1 araçla kaydet, özetlerini değerlendir
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
