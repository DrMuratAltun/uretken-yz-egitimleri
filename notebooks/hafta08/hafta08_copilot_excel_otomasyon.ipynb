# %% [markdown]
# # Microsoft Copilot — Excel Otomasyonu
#
# > **Hafta 8 · Yazı, Sunum, Doküman, Ofis** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Formül + grafik + analiz, doğal dilde.
#
# ---

# %% [markdown]
# ## 1. Erişim
#
# Copilot 365 lisansı (kurumsal yaygın). Bireysel: Copilot Pro (28 USD/ay).

# %% [markdown]
# ## 2. Excel'de Açma
#
# Excel ribbon → Copilot. Tablonu seç, "Bu veriyi analiz et" yaz.

# %% [markdown]
# ## 3. Formül Üretimi
#
# "Her satırın yıllık ortalamasını al, sıralı tablo döndür."

# %% [markdown]
# ## 4. Grafik Önerisi
#
# "Bu veriye en uygun grafik nedir?"

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Bir aylık veriyi Copilot ile rapor haline getir
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
