# %% [markdown]
# # Make — RSS → ChatGPT → Telegram
#
# > **Hafta 9 · Otomasyon ve İş Akışları** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Görsel akış editörü, daha güçlü mantık.
#
# ---

# %% [markdown]
# ## 1. Make vs Zapier
#
# Make: visual editör, daha çok step, daha ucuz. Zapier: kolay, popüler entegrasyon.

# %% [markdown]
# ## 2. Senaryo
#
# RSS feed (örn HuggingFace blog) → ChatGPT (Türkçe özet) → Telegram bot (sana gönder).

# %% [markdown]
# ## 3. Hata Yönetimi
#
# Routes, filters, error handlers — production senaryolar için.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Kendi haberlerini takip eden günlük brifing senaryosu kur
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
