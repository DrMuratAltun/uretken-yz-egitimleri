# %% [markdown]
# # Günlük Brifing Telegram Botu
#
# > **Hafta 9 · Otomasyon ve İş Akışları** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Hava durumu + takvim + haber → Türkçe özet → senin Telegram'ına.
#
# ---

# %% [markdown]
# ## 1. BotFather ile Bot Aç
#
# @BotFather → /newbot → token al.

# %% [markdown]
# ## 2. n8n'de Schedule Trigger
#
# Her sabah 09:00 → akış başlasın.

# %% [markdown]
# ## 3. Veri Topla
#
# OpenWeather (hava) + Google Calendar (takvim) + RSS (haber).

# %% [markdown]
# ## 4. Gemini ile Özet
#
# "Bu 3 verikaynağını sıcak, samimi bir Türkçe brifing haline getir."

# %% [markdown]
# ## 5. Telegram'a Gönder
#
# Telegram node → Send Message → senin chat ID'in.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Kendi günlük brifing botunu kur (Hava + Takvim + Mail + Haber)
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
