# %% [markdown]
# # n8n — Self-Hosted Otomasyon
#
# > **Hafta 9 · Otomasyon ve İş Akışları** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Open source, sınırsız, kendi sunucunda.
#
# ---

# %% [markdown]
# ## 1. n8n Cloud vs Self-Hosted
#
# Cloud: 20 USD/ay. Self-hosted: 1 VPS (5 USD/ay), sınırsız.

# %% [markdown]
# ## 2. Docker Kurulum
#
# `docker run -it --rm -p 5678:5678 n8nio/n8n` → localhost:5678

# %% [markdown]
# ## 3. VPS'e Kurulum
#
# Hetzner/DigitalOcean/Oracle Free Tier — Docker Compose ile kalıcı kurulum.

# %% [markdown]
# ## 4. AI Nodes
#
# OpenAI, Gemini, Anthropic, ElevenLabs node'ları hazır.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** n8n'i Docker ile kur, ilk akışı kur
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
