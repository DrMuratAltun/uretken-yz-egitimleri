# %% [markdown]
# # Notion AI + Database Otomasyonu
#
# > **Hafta 9 · Otomasyon ve İş Akışları** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Kişisel CRM/proje paneli — AI destekli.
#
# ---

# %% [markdown]
# ## 1. Database
#
# Notion'da database aç (kişiler, projeler, görevler).

# %% [markdown]
# ## 2. AI Auto-fill
#
# "Bu kişinin LinkedIn URL'inden özgeçmişini doldur" — sütunda AI.

# %% [markdown]
# ## 3. Notion AI Q&A
#
# "Bu projeyle ilgili son hafta neler oldu?" — AI cevap verir.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Kişisel CRM/proje paneli kur, AI sütunlarıyla otomatize et
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
