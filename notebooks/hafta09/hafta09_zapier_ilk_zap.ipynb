# %% [markdown]
# # İlk Zap — Gmail → Sheets + GPT
#
# > **Hafta 9 · Otomasyon ve İş Akışları** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Sıfırdan otomasyon: yeni e-posta gelince GPT özetle, Sheets'e yaz.
#
# ---

# %% [markdown]
# ## 1. Zapier 101
#
# Tetikleyici (Trigger) + Aksiyonlar (Actions) zinciri = Zap.

# %% [markdown]
# ## 2. Adım 1: Trigger
#
# Gmail → "New Email matching search" → konu="kayıt"

# %% [markdown]
# ## 3. Adım 2: GPT Action
#
# OpenAI → "Create Chat Completion" → prompt="Bu e-postayı 2 cümlede özetle"

# %% [markdown]
# ## 4. Adım 3: Sheets Action
#
# Google Sheets → "Create Spreadsheet Row" → sütunlar: tarih, kimden, özet

# %% [markdown]
# ## 5. Test ve Yayınla
#
# Zap'ı test et, başarılıysa "Publish".

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Kendi günlük rutinini otomatize eden 1 Zap kur
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
