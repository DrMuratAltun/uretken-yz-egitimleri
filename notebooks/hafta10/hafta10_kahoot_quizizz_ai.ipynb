# %% [markdown]
# # Kahoot AI + Quizizz AI
#
# > **Hafta 10 · Eğitimciler İçin Üretken YZ** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Etkileşimli sınıf — quiz üretimi otomatik.
#
# ---

# %% [markdown]
# ## 1. Kahoot AI
#
# Kahoot'a "Üretken YZ" yazınca bir konuyla ilgili otomatik quiz çıkarıyor.

# %% [markdown]
# ## 2. Quizizz AI
#
# PDF/web URL'i yükle → otomatik quiz. Türkçe destek var.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** 1 ders için Kahoot + Quizizz quiz üret, sınıfta dene
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
