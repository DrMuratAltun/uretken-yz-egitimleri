# %% [markdown]
# # MEB Rehberi — 45+ Aracın Disipliner Haritası
#
# > **Hafta 10 · Eğitimciler İçin Üretken YZ** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** docs/MEB Yapay Zeka Araçları Öğretmen El Kitabı temelli.
#
# ---

# %% [markdown]
# ## 1. Disiplinler
#
# Türkçe, Matematik, Fen, Sosyal, İngilizce — her biri için 5-10 araç.

# %% [markdown]
# ## 2. Araç Kartı Şablonu
#
# İsim, kullanım amacı, ücretsiz/ücretli, KVKK uyumu, sınıf seviyesi, örnek uygulama.

# %% [markdown]
# ## 3. Branş Spesifik Rehber
#
# Kendi branşına özel 10 araç seç, sırayla dene, kıyasla.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Branşına özel 10 araç testi + sınıfta deneme + rapor
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
