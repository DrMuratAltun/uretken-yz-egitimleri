# %% [markdown]
# # Otomatik Rubrik Üretimi
#
# > **Hafta 10 · Eğitimciler İçin Üretken YZ** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Ödev değerlendirme rubrikleri — saatlik iş, dakikalara iner.
#
# ---

# %% [markdown]
# ## 1. Rubrik Bileşenleri
#
# Kriter + ağırlık + 4 düzey (mükemmel-iyi-orta-zayıf) + her düzey için tanım.

# %% [markdown]
# ## 2. Prompt Şablonu
#
# "6. sınıf bilim dersi proje ödevi için 5 kriterli analitik rubrik üret. Her kriter 4 düzey, her düzey 1 cümle açıklama."

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Kendi mesleğin için 3 rubrik üret, sınıfta uygula
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
