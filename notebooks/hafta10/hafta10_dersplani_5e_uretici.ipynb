# %% [markdown]
# # 5E Modeli ile Ders Planı Üretimi
#
# > **Hafta 10 · Eğitimciler İçin Üretken YZ** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Engage → Explore → Explain → Elaborate → Evaluate.
#
# ---

# %% [markdown]
# ## 1. 5E Modeli
#
# 5 aşamalı ders modeli — bilim eğitiminin altın standardı.

# %% [markdown]
# ## 2. Gemini Gem ile Şablon
#
# Bir Gem yarat: "Sen 5E modeline göre ders planı uzmanısın. MEB müfredatına uygun, 40 dakika için planlar üretirsin."

# %% [markdown]
# ## 3. Çıktı Format
#
# Markdown tablosu: aşama, süre, öğretmen davranışı, öğrenci davranışı, materyal.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** 1 ünitelik (4 ders) plan üret, sınıfta dene
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
