# %% [markdown]
# # Hafta 15 - AI Bitirme Projesi (Capstone) Şablonu
#
# Bu defter, bitirme projeniz için bir şablon ve rehberdir. Her bölümü kendi projenize göre doldurun.
#
# ## Proje Seçenekleri
# | # | Proje | Teknolojiler | Zorluk |
# |---|-------|-------------|--------|
# | A | Fitness Asistanı (Poz Tespiti) | MediaPipe + Gemini | Orta-Zor |
# | B | Film Öneri Sistemi | GenAI + Collaborative Filtering | Orta |
# | C | Bilgi Botu (RAG Pipeline) | ChromaDB + Gemini | Orta |
#
# ---

# %% [markdown]
# # 1. Proje Tanımı ve Problem
#
# ## 1.1 Problem Tanımı
# Projenizin çözdüğü problemi açıkça tanımlayın.
#
# - **Problem nedir?** [Buraya yazın]
# - **Kim etkileniyor?** [Hedef kitle]
# - **Neden önemli?** [Motivasyon]
# - **Mevcut çözümler ve eksiklikleri?** [Literatür/pazar araştırması]
#
# ## 1.2 Proje Hedefleri
# - Hedef 1: ...
# - Hedef 2: ...
# - Hedef 3: ...
#
# ## 1.3 Başarı Kriterleri
# | Metrik | Hedef Değer |
# |--------|-------------|
# | Doğruluk (Accuracy) | >%X |
# | Yanıt Süresi | <X saniye |
# | Kullanıcı Memnuniyeti | >X/5 |

# %%
# Proje bilgileri
PROJE_ADI = "Proje Adınız"
PROJE_TURU = "A"  # A, B veya C
TAKIM_UYELERI = ["İsim 1", "İsim 2"]
TARIH = "2026-03-30"

print(f"Proje: {PROJE_ADI}")
print(f"Tür: {PROJE_TURU}")
print(f"Takım: {', '.join(TAKIM_UYELERI)}")
print(f"Tarih: {TARIH}")

# %% [markdown]
# ---
# # 2. Veri Toplama ve Hazırlama
#
# ## 2.1 Veri Kaynakları
# Kullanacağınız veri kaynaklarını listeleyin.
#
# | Kaynak | Tür | Boyut | Lisans |
# |--------|-----|-------|--------|
# | ... | CSV/API/Web | ... satır | ... |
#
# ## 2.2 Veri Toplama

# %%
# Gerekli kütüphaneleri yükleyin
# !pip install -q google-generativeai pandas numpy matplotlib scikit-learn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Veri yükleme
# df = pd.read_csv("veri.csv")
# VEYA
# API'den veri çekme
# VEYA
# Web scraping

# Örnek: Veri seti bilgisi
# print(f"Veri boyutu: {df.shape}")
# print(f"Sütunlar: {df.columns.tolist()}")
# df.head()

# %% [markdown]
# ## 2.3 Veri Temizleme ve Ön İşleme

# %% [markdown]
# ### Veri Ön İşleme
#
# Modeli eğitmeden önce veriyi temizliyoruz ve dönüştürüyoruz. Eksik değerleri doldurma, kategorik değişkenleri sayıya çevirme ve ölçeklendirme bu adımın parçasıdır.

# %%
# Eksik değer kontrolü
# print(df.isnull().sum())

# Veri temizleme adımları
# 1. Eksik değerleri doldur/kaldır
# 2. Aykırı değerleri tespit et
# 3. Veri tiplerini düzelt
# 4. Normalizasyon/standardizasyon
# 5. Kategorik değişkenleri kodla

print("Veri temizleme adımlarınızı buraya yazın.")

# %% [markdown]
# ## 2.4 Keşifsel Veri Analizi (EDA)

# %% [markdown]
# ### Temel İstatistikler
#
# Verinin genel yapısını inceliyoruz: sütun tipleri, eksik değerler, temel istatistikler (ortalama, medyan, min, max). Bu bilgiler veri temizleme ve ön işleme adımlarını planlamak için gereklidir.

# %%
# Temel istatistikler
# df.describe()

# Görselleştirmeler
# fig, axes = plt.subplots(2, 2, figsize=(14, 10))
# ...
# plt.tight_layout()
# plt.show()

print("EDA görselleştirmelerinizi buraya ekleyin.")

# %% [markdown]
# ---
# # 3. Model Mimarisi
#
# ## 3.1 Mimari Diyagramı
#
# Projenizin genel mimarisini açıklayın.
#
# ```
# [Giriş] → [Ön İşleme] → [Model] → [Son İşleme] → [Çıkış]
# ```
#
# ## 3.2 Teknoloji Seçimleri
#
# | Bileşen | Teknoloji | Gerekçe |
# |---------|-----------|----------|
# | AI Model | Gemini 2.5 Flash | ... |
# | Vektör DB | ChromaDB | ... |
# | Arayüz | Gradio/Streamlit | ... |
# | ... | ... | ... |

# %%
# Model kurulumu
# import google.generativeai as genai
# genai.configure(api_key="YOUR_API_KEY")
# model = genai.GenerativeModel('gemini-2.5-flash')

print("Model kurulum kodunuzu buraya yazın.")

# %% [markdown]
# ---
# # 4. Eğitim ve Değerlendirme
#
# ## 4.1 Model Eğitimi / Pipeline Kurulumu

# %%
# Ana model/pipeline kodu
# ...

print("Ana model kodunuzu buraya yazın.")

# %% [markdown]
# ## 4.2 Değerlendirme

# %% [markdown]
# ### Performans metrikleri
#
# Aşağıdaki kod bloğunda bu işlemi gerçekleştiriyoruz.

# %%
# Performans metrikleri
# accuracy, precision, recall, f1 veya
# BLEU, ROUGE (metin üretimi için) veya
# kullanıcı testi sonuçları

print("Değerlendirme metriklerinizi buraya yazın.")

# %% [markdown]
# ---
# # 5. Demo ve Arayüz (Gradio / Streamlit)
#
# Projenizi interaktif bir arayüzle sunun.

# %%
# !pip install -q gradio
# import gradio as gr

# def tahmin_yap(girdi):
#     """Ana tahmin fonksiyonu."""
#     # Model çağrısı
#     sonuc = "..."
#     return sonuc

# demo = gr.Interface(
#     fn=tahmin_yap,
#     inputs=gr.Textbox(label="Giriş"),
#     outputs=gr.Textbox(label="Çıkış"),
#     title=PROJE_ADI,
#     description="Proje açıklaması"
# )

# demo.launch()

print("Arayüz kodunuzu buraya yazın.")

# %% [markdown]
# ---
# # 6. Sonuçlar ve Gelecek Çalışmalar
#
# ## 6.1 Sonuçlar
# - Ana bulgu 1: ...
# - Ana bulgu 2: ...
# - Ana bulgu 3: ...
#
# ## 6.2 Kısıtlamalar
# - Kısıt 1: ...
# - Kısıt 2: ...
#
# ## 6.3 Gelecek Çalışmalar
# - İyileştirme 1: ...
# - İyileştirme 2: ...
# - İyileştirme 3: ...
#
# ## 6.4 Öğrenilen Dersler
# - ...
# - ...
#
# ---

# %% [markdown]
# # Proje Seçeneği A: Fitness Asistanı (Poz Tespiti)
#
# MediaPipe ile vücut pozisyonunu tespit edip Gemini ile egzersiz tavsiyeleri veren sistem.
#
# ### Mimari
# ```
# [Kamera/Görüntü] → [MediaPipe Pose] → [Eklem Açıları] → [Gemini] → [Geri Bildirim]
# ```

# %%
# Fitness Asistanı örnek kodu

# !pip install -q mediapipe opencv-python google-generativeai

# import mediapipe as mp
# import cv2
# import numpy as np
# import google.generativeai as genai

# # MediaPipe Pose kurulumu
# mp_pose = mp.solutions.pose
# mp_drawing = mp.solutions.drawing_utils
# pose = mp_pose.Pose(
#     static_image_mode=True,
#     min_detection_confidence=0.5
# )

# def aci_hesapla(a, b, c):
#     """Üç nokta arasındaki açıyı hesapla."""
#     a = np.array(a)
#     b = np.array(b)
#     c = np.array(c)
#     radians = np.arctan2(c[1]-b[1], c[0]-b[0]) - np.arctan2(a[1]-b[1], a[0]-b[0])
#     angle = np.abs(radians * 180.0 / np.pi)
#     if angle > 180.0:
#         angle = 360 - angle
#     return angle

# def poz_analiz_et(image_path):
#     """Görüntüdeki pozu analiz et."""
#     image = cv2.imread(image_path)
#     image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#     results = pose.process(image_rgb)
#     
#     if results.pose_landmarks:
#         landmarks = results.pose_landmarks.landmark
#         # Eklem açılarını hesapla
#         # Gemini'ye gönder ve geri bildirim al
#         pass
#     return results

print("Fitness Asistanı: MediaPipe + Gemini ile poz analizi")
print("Kodu kendi projenize göre tamamlayın.")

# %% [markdown]
# # Proje Seçeneği B: Film Öneri Sistemi
#
# GenAI destekli kişiselleştirilmiş film öneri sistemi.
#
# ### Mimari
# ```
# [Kullanıcı Tercihleri] → [Collaborative Filtering] → [Aday Filmler] → [Gemini Reranking] → [Öneriler]
# ```

# %%
# Film Öneri Sistemi örnek kodu

# import pandas as pd
# import numpy as np
# from sklearn.metrics.pairwise import cosine_similarity
# import google.generativeai as genai

# # Örnek film veritabanı
# filmler = pd.DataFrame({
#     'film_id': range(1, 11),
#     'baslik': ['Yüzüklerin Efendisi', 'Matrix', 'Inception', 'Interstellar',
#                'The Godfather', 'Pulp Fiction', 'Forrest Gump', 'Titanic',
#                'Avatar', 'The Dark Knight'],
#     'tur': ['Fantezi', 'Bilim Kurgu', 'Bilim Kurgu', 'Bilim Kurgu',
#             'Suç', 'Suç', 'Drama', 'Romantik', 'Bilim Kurgu', 'Aksiyon'],
#     'puan': [8.8, 8.7, 8.8, 8.6, 9.2, 8.9, 8.8, 7.9, 7.8, 9.0]
# })

# # Kullanıcı-film puan matrisi (collaborative filtering için)
# puanlar = np.array([
#     [5, 4, 5, 4, 0, 0, 3, 0, 4, 5],  # Kullanıcı 1
#     [0, 5, 4, 5, 1, 2, 0, 0, 5, 4],  # Kullanıcı 2
#     [1, 0, 0, 0, 5, 5, 4, 3, 0, 3],  # Kullanıcı 3
#     [4, 3, 4, 3, 0, 0, 5, 4, 3, 2],  # Kullanıcı 4
# ])

# def benzer_kullanicilari_bul(kullanici_idx, puan_matrisi, n=2):
#     """Kosinüs benzerliği ile en benzer kullanıcıları bul."""
#     benzerlikler = cosine_similarity([puan_matrisi[kullanici_idx]], puan_matrisi)[0]
#     benzer_idx = np.argsort(benzerlikler)[::-1][1:n+1]
#     return benzer_idx, benzerlikler[benzer_idx]

# def gemini_ile_oneriler_acikla(film_listesi, kullanici_tercihleri):
#     """Gemini ile önerilerin nedenini açıkla."""
#     prompt = f"""Kullanıcının beğendiği filmler: {kullanici_tercihleri}
#     Önerilen filmler: {film_listesi}
#     Her film için neden önerildiğini kısaca açıkla."""
#     response = model.generate_content(prompt)
#     return response.text

print("Film Öneri Sistemi: Collaborative Filtering + Gemini")
print("Kodu kendi projenize göre tamamlayın.")

# %% [markdown]
# # Proje Seçeneği C: Bilgi Botu (RAG Pipeline)
#
# Belirli bir konu hakkında uzman bilgi botu.
#
# ### Mimari
# ```
# [Belgeler] → [Parçalama] → [Embedding] → [ChromaDB]
#                                               ↓
# [Kullanıcı Sorusu] → [Embedding] → [Benzerlik Araması] → [Bağlam + Soru] → [Gemini] → [Yanıt]
# ```

# %%
# Bilgi Botu örnek kodu

# import google.generativeai as genai
# import chromadb

# class BilgiBotu:
#     """RAG tabanlı bilgi botu."""
#     
#     def __init__(self, api_key, koleksiyon_adi="bilgi_bankasi"):
#         genai.configure(api_key=api_key)
#         self.model = genai.GenerativeModel('gemini-2.5-flash')
#         self.chroma = chromadb.Client()
#         self.koleksiyon = self.chroma.get_or_create_collection(koleksiyon_adi)
#     
#     def belge_ekle(self, belgeler):
#         """Belgeleri vektör veritabanına ekle."""
#         for belge in belgeler:
#             embedding = genai.embed_content(
#                 model="models/embedding-001",
#                 content=belge['metin'],
#                 task_type="retrieval_document"
#             )['embedding']
#             
#             self.koleksiyon.add(
#                 ids=[belge['id']],
#                 embeddings=[embedding],
#                 documents=[belge['metin']],
#                 metadatas=[belge.get('meta', {})]
#             )
#     
#     def soru_sor(self, soru, n_sonuc=3):
#         """RAG ile soru yanıtla."""
#         # 1. Soru embedding'i
#         soru_emb = genai.embed_content(
#             model="models/embedding-001",
#             content=soru,
#             task_type="retrieval_query"
#         )['embedding']
#         
#         # 2. Benzer belgeleri bul
#         sonuclar = self.koleksiyon.query(
#             query_embeddings=[soru_emb],
#             n_results=n_sonuc
#         )
#         
#         # 3. Bağlam oluştur ve Gemini'ye gönder
#         baglam = "\n".join(sonuclar['documents'][0])
#         prompt = f"Bağlam:\n{baglam}\n\nSoru: {soru}\n\nYanıt:"
#         response = self.model.generate_content(prompt)
#         return response.text

print("Bilgi Botu: ChromaDB + Gemini RAG Pipeline")
print("Kodu kendi projenize göre tamamlayın.")

# %% [markdown]
# ---
# # Değerlendirme Rubriği
#
# Projeniz aşağıdaki kriterlere göre değerlendirilecektir:
#
# | Kriter | Ağırlık | Puan (1-5) | Açıklama |
# |--------|---------|------------|----------|
# | **Problem Tanımı** | %10 | _ /5 | Problemin net tanımı, motivasyon, hedefler |
# | **Veri Hazırlama** | %15 | _ /5 | Veri toplama, temizleme, EDA kalitesi |
# | **Model/Pipeline** | %25 | _ /5 | Teknik uygulama, mimari tasarım, kod kalitesi |
# | **Değerlendirme** | %15 | _ /5 | Doğru metrik seçimi, kapsamlı test, sonuç analizi |
# | **Demo/Arayüz** | %15 | _ /5 | Çalışan demo, kullanıcı deneyimi |
# | **Sunum** | %10 | _ /5 | Anlatım, slayt kalitesi, zaman yönetimi |
# | **Dokümantasyon** | %10 | _ /5 | Kod yorumları, README, kullanım kılavuzu |
# | **TOPLAM** | %100 | _ /5 | |
#
# ### Puan Açıklamaları
# - **5 (Mükemmel):** Beklentilerin üzerinde, yaratıcı ve kapsamlı
# - **4 (İyi):** Tüm gereksinimleri karşılıyor, kaliteli iş
# - **3 (Yeterli):** Temel gereksinimleri karşılıyor
# - **2 (Geliştirilmeli):** Eksiklikler var, iyileştirme gerekli
# - **1 (Yetersiz):** Temel gereksinimler karşılanmamış
#
# ### Bonus Puanlar (+0.5 her biri)
# - Canlı deploy (Hugging Face Spaces, Streamlit Cloud vb.)
# - Kapsamlı hata yönetimi
# - Birim testleri
# - Etik değerlendirme bölümü
# - Kullanıcı testi sonuçları

# %% [markdown]
# ---
# # Deploy Kontrol Listesi
#
# Projenizi yayınlamadan önce aşağıdaki maddeleri kontrol edin:
#
# ## Kod Kalitesi
# - [ ] Tüm kod hücreleri sırayla çalışıyor
# - [ ] Gereksiz/test kodları temizlendi
# - [ ] Fonksiyonlara docstring eklendi
# - [ ] Değişken isimleri anlamlı ve Türkçe
# - [ ] Hata yönetimi (try/except) eklendi
#
# ## Güvenlik
# - [ ] API anahtarları kodda YOK (environment variable kullanılıyor)
# - [ ] Kişisel veriler anonimleştirildi
# - [ ] .gitignore dosyası güncel
#
# ## Dokümantasyon
# - [ ] README.md yazıldı (kurulum, kullanım, örnekler)
# - [ ] requirements.txt oluşturuldu
# - [ ] Proje yapısı açıklandı
#
# ## Test
# - [ ] En az 5 farklı girdi ile test edildi
# - [ ] Edge case'ler (boş girdi, uzun metin, hatalı veri) test edildi
# - [ ] Performans metrikleri raporlandı
#
# ## Deploy (Opsiyonel)
# - [ ] Gradio/Streamlit arayüzü çalışıyor
# - [ ] Hugging Face Spaces veya Streamlit Cloud'a yüklendi
# - [ ] Demo bağlantısı README'ye eklendi
#
# ## Sunum
# - [ ] Slaytlar hazırlandı (max 15 slayt)
# - [ ] Canlı demo planlandı
# - [ ] Sunum süresi kontrol edildi (10-15 dakika)
# - [ ] Soru-cevap için hazırlık yapıldı

# %%
# Son kontrol: requirements.txt oluşturma
requirements = """
# Temel
google-generativeai
pandas
numpy
matplotlib
scikit-learn

# Proje A (Fitness) için ekleyin:
# mediapipe
# opencv-python

# Proje B (Film Öneri) için ekleyin:
# (temel paketler yeterli)

# Proje C (RAG) için ekleyin:
# chromadb

# Arayüz
# gradio
# VEYA
# streamlit
"""

print("requirements.txt içeriği:")
print(requirements)
print("\nBu dosyayı proje dizininize kaydedin:")
print("with open('requirements.txt', 'w') as f:")
print("    f.write(requirements)")

# %% [markdown]
# ---
#
# ## Başarılar!
#
# Bu şablonu kendi projenize uyarlayın. Her bölümü doldurarak kapsamlı bir bitirme projesi ortaya koyun.
#
# Sorularınız için derste veya iletişim kanallarından ulaşabilirsiniz.
