# %% [markdown]
# # Perplexity Spaces ile Araştırma Akışı
#
# > **Hafta 3 · Sohbet Asistanları** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Arama tabanlı asistanlar — kaynak gösteren, gerçek zamanlı bilgi.
#
# ---

# %% [markdown]
# ## 1. Perplexity vs ChatGPT
#
# Perplexity her cevaba kaynak gösterir + güncel webdir. ChatGPT eski bilgiyi sentezler. Araştırma için Perplexity, yaratıcılık için ChatGPT.

# %% [markdown]
# ## 2. Spaces
#
# Bir konu = bir Space. Belirli kaynaklara odaklan (ör: sadece arxiv.org + GitHub).

# %% [markdown]
# ## 3. Pro Search vs Deep Research
#
# Pro Search: 1-2 dakikada cevap. Deep Research: 5-10 dakika, 30+ kaynak tarar, rapor yazar.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Bir araştırma sorusunu Perplexity Deep Research ile çözdür, kaynak listesini değerlendir
# **Görev 2.** Kendi alanına özel 1 Space oluştur
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
