# %% [markdown]
# # ChatGPT Custom GPT Atölyesi
#
# > **Hafta 3 · Sohbet Asistanları** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Kendi GPT'ni adım adım yarat — sistem prompt'u, bilgi tabanı, eylemler.
#
# ---

# %% [markdown]
# ## 🎯 Hedefler
#
# Bu notebook'u tamamladığında:
#
# - Custom GPT yaratma 5 adımını uygulamak
# - Knowledge base ile doküman bağlamak
# - Actions ile API entegrasyonu görmek
#
# ---

# %% [markdown]
# ## 1. 1. Adım: Builder'ı aç
#
# ChatGPT Plus → "Explore GPTs" → "Create" → Builder ile sohbet ederek tanımla.

# %% [markdown]
# ## 2. 2. Adım: Sistem Prompt'u
#
# Hafta 2'de öğrendiğin 6'lı yapı (Rol+Bağlam+Görev+Kısıt+Format+Örnek) ile sistem prompt'u yaz.

# %% [markdown]
# ## 3. 3. Adım: Knowledge
#
# 20'ye kadar dosya yükleyebilirsin (PDF, DOCX). GPT bunlardan RAG yapar.

# %% [markdown]
# ## 4. 4. Adım: Capabilities
#
# Web Browser, DALL-E, Code Interpreter — gerekenleri aç/kapat.

# %% [markdown]
# ## 5. 5. Adım: Test ve Yayınla
#
# "Only me", "Only with link", "Public" — paylaşım seviyesini seç.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Kendi alanına özel 1 Custom GPT yarat, link paylaş
# **Görev 2.** 5 farklı sistem prompt'u dene, kalite farkını gözlemle
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
