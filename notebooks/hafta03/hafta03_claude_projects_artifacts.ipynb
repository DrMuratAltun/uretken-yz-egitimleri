# %% [markdown]
# # Claude Projects ve Artifacts
#
# > **Hafta 3 · Sohbet Asistanları** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Claude'un proje bazlı çalışma + canlı kod/HTML önizleme yetenekleri.
#
# ---

# %% [markdown]
# ## 1. Projects
#
# Bir proje = paylaşılan bağlam + dosyalar + sistem prompt'u. Bir hafta boyunca aynı proje üzerinden devam edebilirsin.

# %% [markdown]
# ## 2. Artifacts
#
# Claude'un kod, HTML, mermaid diyagram, react component üretimini canlı önizleyen panel. "Kodu burada göster, ben düzelteyim" akışı.

# %% [markdown]
# ## 3. Computer Use (önizleme)
#
# Claude'un browser'ı ya da masaüstünü kontrol etmesi. Anthropic API ile kullanılır.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** 1 Claude Project oluştur, 5 dosya bağla, hafta boyu kullan
# **Görev 2.** 1 Artifact ile küçük bir landing page üret
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
