# %% [markdown]
# # Sohbet Asistanları Kıyas Matrisi
#
# > **Hafta 3 · Sohbet Asistanları** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** ChatGPT, Gemini, Claude, Grok, DeepSeek — 10 görev × 5 araç kıyas tablosu
#
# ---

# %% [markdown]
# ## 🎯 Hedefler
#
# Bu notebook'u tamamladığında:
#
# - Maliyet vs hız vs doğruluk dengelemek
# - 5 aracın güçlü/zayıf yanını ezbere bilmek
#
# ---

# %% [markdown]
# ## 1. Maliyet ve Erişim
#
# Free tier limitleri, premium fiyatlar (USD/ay), Türkiye'den erişim.
#
# - ChatGPT Plus: 20 USD/ay, GPT-5 + o3 + Sora
# - Gemini Advanced: 19 USD/ay (Türkiye direkt)
# - Claude Pro: 20 USD/ay, Opus + Sonnet 4.6 + 4.7
# - Grok: X Premium ile, 8 USD
# - DeepSeek: Tamamen ücretsiz (web)

# %% [markdown]
# ## 2. Türkçe Performans
#
# Aynı 10 Türkçe soruyu 5 araca sor, doğruluk + üslup karşılaştır. Türk argosu, deyimler, bölgesel ifadelerde fark belirginleşir.

# %% [markdown]
# ## 3. Özel Yetenekler
#
# - ChatGPT: Code Interpreter, Sora, Memory
# - Gemini: 2M context, Deep Research, Veo
# - Claude: Computer Use, Artifacts, MCP
# - Grok: X gerçek zamanlı arama, Think mode
# - DeepSeek: Açık ağırlık, ücretsiz reasoning

# %% [markdown]
# ## 4. Kıyas Tablosu Şablonu
#
# Bir Excel/Sheets dosyası oluştur. Kolonlar: Görev, ChatGPT, Gemini, Claude, Grok, DeepSeek. Satırlar: 10 görev. Her hücreye 1-5 puan + kısa not.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** 10 mesleki görevi 5 araca sor, kıyas raporu yaz
# **Görev 2.** En sık kullandığın aracın "yapamadığı" 3 şeyi bul, alternatife geç
# **Görev 3.** Aile/iş için kişisel asistan paneli hazırla (hangi araç, hangi durumda)
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
