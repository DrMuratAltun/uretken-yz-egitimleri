# %% [markdown]
# # Gemini Gems ile Kişisel Asistan
#
# > **Hafta 3 · Sohbet Asistanları** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Gemini'nin Custom GPT muadili olan Gems'i atölye formatında öğren.
#
# ---

# %% [markdown]
# ## 1. Gem nedir?
#
# Gemini Advanced'a özel kişisel asistan tanımlama özelliği. Sistem prompt + Knowledge + Connectors (Drive, Gmail, Docs).

# %% [markdown]
# ## 2. Türkçe için ipuçları
#
# Türkçe yanıt için sistem prompt'una "TÜRKÇE YANITLA" yaz, dil kilidi at. Gemini bazı durumlarda otomatik İngilizce kayar.

# %% [markdown]
# ## 3. Drive Bağlantısı
#
# Gem'e Google Drive klasörü bağlayabilirsin — RAG otomatik.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** 1 mesleki Gem yarat, link paylaş
# **Görev 2.** Drive klasörü bağla, soru-cevap dene
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
