# %% [markdown]
# # Veo 3 — Google AI Studio (Ücretsiz)
#
# > **Hafta 7 · Video, Avatar, Animasyon** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Türkiye'den direkt, 8 saniyelik videolar.
#
# ---

# %% [markdown]
# ## 1. Erişim
#
# aistudio.google.com → Veo → Free tier

# %% [markdown]
# ## 2. Prompt İpuçları
#
# Sahne + kamera hareketi + ışık + ton: "Bir kafede oturan kadın, kamera yavaş zoom, golden hour ışık, sıcak ton"

# %% [markdown]
# ## 3. Sınırlar
#
# 8 saniye, 1080p, haftalık kota.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** 1 dakikalık tanıtım videon için 8 saniyelik 8 sahne üret, CapCut'ta birleştir
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
