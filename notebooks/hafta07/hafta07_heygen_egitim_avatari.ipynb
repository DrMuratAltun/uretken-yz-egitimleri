# %% [markdown]
# # HeyGen — Türkçe Eğitim Avatarı
#
# > **Hafta 7 · Video, Avatar, Animasyon** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Konuşan avatar, Türkçe destekli.
#
# ---

# %% [markdown]
# ## 1. Foto Avatar
#
# Tek fotoğraf + metin → konuşan avatar (15 sn ücretsiz).

# %% [markdown]
# ## 2. Voice Clone Avatar
#
# Kendi sesini + kendi yüzünü klonla. Premium.

# %% [markdown]
# ## 3. Eğitim Senaryosu
#
# Tarihi karakter canlandırma, sürekli "öğretmen avatar" — öğrencilerin alışkanlığı için.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Tarihi/edebi karakteri canlandıran 3 dakikalık avatar dersi
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
