# %% [markdown]
# # Uçtan Uca Pipeline — Senaryodan Videoya
#
# > **Hafta 7 · Video, Avatar, Animasyon** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Senaryo (LLM) → Görsel (Imagen) → Ses (ElevenLabs) → Video (Veo) → Edit (CapCut).
#
# ---

# %% [markdown]
# ## 1. Aşama 1: Senaryo
#
# ChatGPT/Gemini ile 60 saniyelik sahne sahne senaryo.

# %% [markdown]
# ## 2. Aşama 2: Görseller
#
# Her sahne için Imagen ile 1 görsel.

# %% [markdown]
# ## 3. Aşama 3: Seslendirme
#
# ElevenLabs ile Türkçe dublaj.

# %% [markdown]
# ## 4. Aşama 4: Hareket
#
# Görselleri Runway/Luma image-to-video ile 5 saniye animasyon.

# %% [markdown]
# ## 5. Aşama 5: Birleştirme
#
# CapCut'ta tüm parçalar + altyazı + müzik.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Bir konu için 60 saniyelik tanıtım videosu — uçtan uca tek başına yap
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
