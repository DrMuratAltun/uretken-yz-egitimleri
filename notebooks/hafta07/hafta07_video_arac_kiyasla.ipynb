# %% [markdown]
# # 5 Video Aracı Kıyası
#
# > **Hafta 7 · Video, Avatar, Animasyon** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Sora, Veo, Kling, Runway, Pika — aynı promptla.
#
# ---

# %% [markdown]
# ## 1. Test Promptu
#
# "Üretken YZ ile çocuk eğitimi yapan bir öğretmen, sınıfta tablet kullanıyor, doğal ışık, fotogerçekçi"

# %% [markdown]
# ## 2. Erişim
#
# Veo (Google AI Studio, ücretsiz), Sora (ChatGPT Plus), Kling (kling.ai), Runway (runway.ml), Pika (pika.art)

# %% [markdown]
# ## 3. Değerlendirme
#
# Süre, kalite, hareketin tutarlılığı, fotogerçekçilik, prompt sadakati

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** 5 araçtan 5 video üret, kıyas posteri yap
# **Görev 2.** Hangisi mesleğine en uygun, raporla
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
