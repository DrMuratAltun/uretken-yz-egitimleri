# %% [markdown]
# # Multimodal Gemini — Uzun Video → Özet
#
# > **Hafta 7 · Video, Avatar, Animasyon** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Gemini 2.5'in 2M context'i ile 1 saatlik video → 5 paragraf.
#
# ---

# %% [markdown]
# ## 1. Video Yükleme
#
# aistudio.google.com → Files → upload (1 saate kadar)

# %% [markdown]
# ## 2. Prompt
#
# "Bu videodaki 5 ana noktayı çıkar, her birini 1 paragrafla özetle."

# %% [markdown]
# ## 3. Geri Bildirim Üretici
#
# Öğrenci sunumunu izlet, otomatik geri bildirim raporu üret.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Bir 30 dakikalık öğrenci sunumunu Gemini'ye izlet, geri bildirim raporu üret
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
