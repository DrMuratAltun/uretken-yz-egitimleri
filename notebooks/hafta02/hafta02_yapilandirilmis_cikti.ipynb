# %% [markdown]
# # Yapılandırılmış Çıktı — JSON, Tablo, Markdown
#
# > **Hafta 2 · Prompt Mühendisliği** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Modelin cevabını otomasyona/diğer araçlara verebilmek için yapılandırılmış çıktı talep etmek.
#
# ---

# %% [markdown]
# ## 🎯 Hedefler
#
# Bu notebook'u tamamladığında:
#
# - JSON, tablo ve markdown çıktı şablonları yazmak
# - Çıktıyı doğrudan başka bir araca beslemek
#
# ---

# %% [markdown]
# ## 1. Neden Yapılandırılmış Çıktı?
#
# Düz metin → insan okur. JSON/tablo → bilgisayar okur. Otomasyon (Hafta 9), API (Hafta 14), n8n akışı için olmazsa olmaz.

# %% [markdown]
# ## 2. JSON Çıktı
#
# **Prompt:**
# ```
# Aşağıdaki yorumdan duygu, ürün özelliği ve şikayet kategorisini çıkar.
# Çıktı şu JSON formatında olsun:
# {
#   "duygu": "POZ|NEG|NÖT",
#   "ozellik": "...",
#   "sikayet_kategorisi": "kargo|kalite|fiyat|diğer|yok"
# }
#
# Yorum: "Ürün güzel ama kargo 2 hafta sürdü, çileden çıkardı."
# ```

# %% [markdown]
# ## 3. Markdown Tablo
#
# "Aşağıdaki 5 LLM aracını maliyet, hız, Türkçe doğruluk açısından markdown tablosu olarak kıyasla: ChatGPT, Gemini, Claude, Grok, DeepSeek."

# %% [markdown]
# ## 4. Listeleme + Numaralı
#
# "5 maddelik kontrol listesi, her madde 1 cümle, her cümlede maksimum 12 kelime."

# %% [markdown]
# ## 5. Pydantic / Schema (ileri)
#
# OpenAI ve Gemini, yapılandırılmış çıktı için "Schema" desteği sunar. Hafta 14'te API ile derinleşeceğiz.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Kendi mesleğine özel bir form (JSON) tanımla. ChatGPT'ye 10 örnek girdiyi formla doldurt.
# **Görev 2.** 5 araçlı kıyas tablosu prompt'u yaz, sonucu Notion'a kopyala.
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
