# %% [markdown]
# # Pazarlama + SEO + İçerik
#
# > **Hafta 11 · Mesleğe Özel Atölyeler** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Jasper, Copy.ai, SurferSEO, Frase.
#
# ---

# %% [markdown]
# ## 1. Jasper
#
# Pazarlama içeriği özelinde hızlı şablonlar.

# %% [markdown]
# ## 2. SurferSEO
#
# Anahtar kelime odaklı blog yazısı + SEO skor.

# %% [markdown]
# ## 3. Frase
#
# Soru-cevap odaklı içerik (People Also Ask + AI).

# %% [markdown]
# ## 4. Karşılaştırma
#
# ChatGPT genel amaçlı; Jasper/Surfer pazarlamaya optimize.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Bir blog yazısı 3 araçla üret, kıyas yap
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
