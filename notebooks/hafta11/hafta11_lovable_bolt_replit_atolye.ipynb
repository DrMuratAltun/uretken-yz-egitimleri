# %% [markdown]
# # Lovable / Bolt.new / Replit Agent
#
# > **Hafta 11 · Mesleğe Özel Atölyeler** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** No-code uygulama — fikir → çalışan ürün, 1 saatte.
#
# ---

# %% [markdown]
# ## 1. Lovable
#
# lovable.dev — prompt → tam stack web uygulaması (React + DB).

# %% [markdown]
# ## 2. Bolt.new
#
# bolt.new — StackBlitz + AI, anında preview.

# %% [markdown]
# ## 3. Replit Agent
#
# replit.com → Agent → otonom kod yazma.

# %% [markdown]
# ## 4. Karşılaştırma
#
# Lovable: en güzel UI. Bolt: en hızlı. Replit: en otonom.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Fikrini 1 saatte canlı uygulamaya çevir (Lovable veya Bolt ile)
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
