# %% [markdown]
# # Sağlık / Hukuk / Finans Dikey Araçlar
#
# > **Hafta 11 · Mesleğe Özel Atölyeler** · *Üretken YZ Atölyesi · Dr. Murat Altun*
#
# **Bu notebook hakkında:** Branşa özel asistanlar.
#
# ---

# %% [markdown]
# ## 1. Sağlık: OpenEvidence + Doximity GPT
#
# Klinik karar destek, hekimlere özel.

# %% [markdown]
# ## 2. Hukuk: Harvey AI + Lexis+ AI
#
# Dava analizi, sözleşme inceleme.

# %% [markdown]
# ## 3. Finans: Bloomberg GPT + FinChat
#
# Piyasa analizi, finansal tablolar.

# %% [markdown]
# ## 4. Etik & Uyum
#
# Her dikey araç KVKK + meslek odası kuralları altında.

# %% [markdown]
# ---
#
# ## 🛠️ Sen Yap — Atölye Görevleri
#
# **Görev 1.** Mesleğine uygun 1 dikey aracı dene, etik raporu yaz
#
# > Çıktılarını öğrenme defterine kaydet, capstone projesinde tekrar kullanırsın.

# %% [markdown]
# ---
#
# ## 📚 Sıradaki
#
# Bir sonraki notebook ile atölye akışına devam et.
#
# *— Üretken YZ Atölyesi · Prompttan Ürüne · Dr. Murat Altun · 2026*
